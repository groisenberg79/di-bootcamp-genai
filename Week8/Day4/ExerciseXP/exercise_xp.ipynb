# %% [markdown]
# ## 🌟 Exercise 1 : Matrix Operations
# ### Instructions
# In this exercise, you’ll work with a 3x3 matrix. Here’s a brief explanation of the concepts:
#
# - **Determinant**: The determinant is a value that can be computed from the elements of a square matrix. It provides important information about the matrix, such as whether it has an inverse, and is used in various areas like linear algebra and calculus.
# - **Inverse of a Matrix**: The inverse of a matrix is a matrix that, when multiplied with the original matrix, results in an identity matrix. Not all matrices have inverses. The inverse is crucial in solving systems of linear equations.
#
# Create a 3x3 matrix and perform the following operations:
#
# 1. Calculate the determinant.
# 2. Find the inverse of the matrix.

# %% [markdown]
# ### Solution

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Display settings
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
plt.style.use('seaborn-v0_8-whitegrid')

# %%
# Create a default random number generator
rng = np.random.default_rng(seed = 42)

# Generate a 3x3 matrix of random integers
# Parameters: low (0), high (10 - exclusive), size ((3, 3))
mat = rng.integers(low=0, high=10, size=(3,3))

print("the matrix:")
print(mat)
print()

det = np.linalg.det(mat)
print(f"The determinant: {det}")
print()

inv = np.linalg.inv(mat)
print("the inverse:")
print(inv)
print()
# Out:
# the matrix:
# [[0 7 6]
#  [4 4 8]
#  [0 6 2]]
#
# The determinant: 87.99999999999996
#
# the inverse:
# [[-0.45454545  0.25        0.36363636]
#  [-0.09090909  0.          0.27272727]
#  [ 0.27272727 -0.         -0.31818182]]

# %% [markdown]
# ## 🌟 Exercise 2 : Statistical Analysis
# ### Instructions
# In this exercise, you’ll calculate statistical measures for a dataset:
#
# - **Mean**: The average value of a dataset.
# - **Median**: The middle value in a dataset when it is arranged in ascending or descending order.
# - **Standard Deviation**: A measure of the amount of variation or dispersion in a set of values.
#
# Using NumPy, generate an array of 50 random numbers and compute:
#
# 1. The mean and median.
# 2. The standard deviation.

# %% [markdown]
# ### Solution

# %%
# Generate an array of 50 random floats in the half-open interval [0.0, 50)
random_floats = 50 * rng.random(50).round(1)
print(random_floats)
print()

print(f"mean: {np.mean(random_floats)}")
print(f"median: {np.median(random_floats)}")
print(f"standard deviation: {np.std(random_floats)}")
# Out:
# [50. 40. 40.  5. 25. 20. 45. 30. 40. 20. 10. 30.  5. 40. 30. 40. 20. 50.
#  45. 40. 10. 25.  0. 10. 35. 35. 50. 15. 20. 25. 10.  5. 25. 10. 35. 20.
#  40. 35. 15. 40. 40. 20. 15. 35.  5. 10.  0. 40. 35. 35.]
#
# mean: 26.4
# median: 27.5
# standard deviation: 14.319217855734998

# %% [markdown]
# ## 🌟 Exercise 3 : Date Manipulation
# ### Instructions
# Create a NumPy array of dates for the month of January 2023. Convert these dates to another format (e.g., YYYY/MM/DD).

# %% [markdown]
# ### Solution

# %%
jan_dates = np.arange('2023-01-01', '2023-02-01', dtype='datetime64[D]').astype(str)
print(f"january dates:")
print(jan_dates)
print()

# Convert to YYYY/MM/DD format
formatted = np.char.replace(jan_dates, '-', '/')  # replace '-' with '/'
print("Format YYYY/MM/DD: ")
print(formatted)
# Out:
# january dates:
# ['2023-01-01' '2023-01-02' '2023-01-03' '2023-01-04' '2023-01-05'
#  '2023-01-06' '2023-01-07' '2023-01-08' '2023-01-09' '2023-01-10'
#  '2023-01-11' '2023-01-12' '2023-01-13' '2023-01-14' '2023-01-15'
#  '2023-01-16' '2023-01-17' '2023-01-18' '2023-01-19' '2023-01-20'
#  '2023-01-21' '2023-01-22' '2023-01-23' '2023-01-24' '2023-01-25'
#  '2023-01-26' '2023-01-27' '2023-01-28' '2023-01-29' '2023-01-30'
#  '2023-01-31']
#
# Format YYYY/MM/DD:
# ['2023/01/01' '2023/01/02' '2023/01/03' '2023/01/04' '2023/01/05'
#  '2023/01/06' '2023/01/07' '2023/01/08' '2023/01/09' '2023/01/10'
#  '2023/01/11' '2023/01/12' '2023/01/13' '2023/01/14' '2023/01/15'
#  '2023/01/16' '2023/01/17' '2023/01/18' '2023/01/19' '2023/01/20'
#  '2023/01/21' '2023/01/22' '2023/01/23' '2023/01/24' '2023/01/25'
#  '2023/01/26' '2023/01/27' '2023/01/28' '2023/01/29' '2023/01/30'
#  '2023/01/31']

# %% [markdown]
# ## 🌟 Exercise 4 : Data Manipulation with NumPy and Pandas
# ### Instructions
# Create a DataFrame with random numbers and perform:
#
# 1. Conditional selection of data.
# 2. Aggregation functions like sum and average.

# %% [markdown]
# ### Solution

# %%
# Create a DataFrame where each row is a book
# 1st column: number of pages of the book
# 2nd column: price of the book
# 3rd column: reader rating of the book

num_pages = rng.integers(low=1, high=1000, size=(10,))
price = 100 * rng.random(size=(10,)).round(1) + 1
rating = rng.integers(low=0, high=11, size=(10,))

books = pd.DataFrame(
    {'number_pages': num_pages,
    'price': price,
    'reader_rating': rating}
    )

print("All books:")
print(books)
print()

# Select only books with rating > 5
g_five = books.loc[books['reader_rating'] > 5]
print("Books with ratings greater than 5:")
print(g_five)
print()

# Get total number of pages
print(f"Sum of the number of pages of all books: {books['number_pages'].sum().astype(int)} pages")
print()

# Get the mean rating
print(f"Mean reader rating across all books: {books['reader_rating'].mean()}")
# Out:
# All books:
#    number_pages  price  reader_rating
# 0            95   71.0              1
# 1           277   51.0             10
# 2           780   61.0              2
# 3           556   81.0              3
# 4           459   61.0              4
# 5           506   61.0             10
# 6           569   61.0              9
# 7            38   31.0              0
# 8           140    1.0              2
# 9           246   41.0              9
#
# Books with ratings greater than 5:
#    number_pages  price  reader_rating
# 1           277   51.0             10
# 5           506   61.0             10
# 6           569   61.0              9
# 9           246   41.0              9
#
# Sum of the number of pages of all books: 3666 pages
#
# Mean reader rating across all books: 5.0

# %% [markdown]
# ## 🌟 Exercise 5 : Image Representation
# ### Instructions
# Explain how images are represented in NumPy arrays and demonstrate with a simple example (e.g., creating a 5x5 grayscale image).

# %% [markdown]
# ### Solution
#
# Images in NumPy are represented as multi-dimensional NumPy arrays (ndarrays), where each element in the array is a pixel value or a color component. The array's shape and data type (dtype) determine the image's type and resolution.
#
# #### Representation by Image Type
#
# - **Grayscale Images**: These are typically represented by a two-dimensional (2D) NumPy array with the shape `(height, width)`. Each element is a single number representing the pixel's intensity or luminosity, typically an 8-bit unsigned integer (`uint8`) with values ranging from 0 (black) to 255 (white).
# - **Color (RGB) Images**: These are represented by a three-dimensional (3D) NumPy array with the shape `(height, width, channels)`.
#     - The first two dimensions correspond to the rows and columns of pixels (height and width).
#     - The third dimension, or axis, represents the color channels. For an RGB image, there are three channels (Red, Green, Blue), so the dimension size is 3.
#     - Each pixel is an array of three values, e.g., `[151, 129, 115]` for a specific shade.
#
# - **RGBA Images**: For images with transparency (alpha channel), the 3D array has a shape of `(height, width, 4)`.

# %%
# Create a 5x5 grayscale image - a cross/plus pattern
cross = np.zeros((5, 5), dtype=np.uint8)  # 5x5 array of zeros, dtype=np.uint8

# Draw a cross: fill middle row and middle column with white
cross[2, :] = 255     # middle row = 255
cross[:, 2] = 255     # middle column = 255

# Display it
fig, ax = plt.subplots(figsize=(8, 4))

ax.imshow(cross, cmap='gray', vmin=0, vmax=255)
ax.set_title('Cross Pattern', fontsize=13, fontweight='bold')
for i in range(5):
    for j in range(5):
        ax.text(j, i, str(cross[i, j]), ha='center', va='center',
                     color='red' if cross[i, j] == 0 else 'black', fontsize=10)
ax.set_xticks(range(5))
ax.set_yticks(range(5))

# %% [markdown]
# ## 🌟 Exercise 6 : Basic Hypothesis Testing
# ### Instructions
# Create a sample dataset to test the effectiveness of a new training program on employee productivity:
#
# ```
# import numpy as np
#
# # Productivity scores of employees before the training program
# productivity_before = np.random.normal(loc=50, scale=10, size=30)
#
# # Productivity scores of the same employees after the training program
# productivity_after = productivity_before + np.random.normal(loc=5, scale=3, size=30)
#
# # Your task is to formulate a hypothesis regarding the training program's effectiveness
# # and test it using basic statistical functions in NumPy.
# ```

# %% [markdown]
# ### Solution

# %%
# Productivity scores of employees before the training program
productivity_before = rng.normal(loc=50, scale=10, size=30)

# Productivity scores of the same employees after the training program
productivity_after = productivity_before + rng.normal(loc=5, scale=3, size=30)

# The differences
differences = productivity_after - productivity_before

print("Training Program Data (30 employees):")
print(f"Before: mean = {productivity_before.mean():.2f}, std = {productivity_before.std():.2f}")
print(f"After:  mean = {productivity_after.mean():.2f}, std = {productivity_after.std():.2f}")
print(f"Diff:   mean = {differences.mean():.2f}, std = {differences.std():.2f}")
# Out:
# Training Program Data (30 employees):
# Before: mean = 49.46, std = 11.62
# After:  mean = 54.83, std = 11.73
# Diff:   mean = 5.37, std = 2.70

# %%
# Paired t-test: are the differences significantly different from 0?
# H0: mean difference = 0 (training had no effect)
# H1: mean difference > 0 (training improved productivity)

t_stat, p_value = stats.ttest_1samp(differences, 0)  # one-sample t-test on differences, testing against 0

print("Hypothesis Test Results:")
print(f"  Test statistic (t): {t_stat:.4f}")
print(f"  p-value:            {p_value:.6f}")
print()

alpha = 0.05
if p_value < alpha:
    print(f"  p-value ({p_value:.6f}) < alpha ({alpha})")
    print("  REJECT H0: The training program significantly improved productivity!")
else:
    print(f"  p-value ({p_value:.6f}) >= alpha ({alpha})")
    print("  FAIL TO REJECT H0: Not enough evidence that training had an effect.")
# Out:
# Hypothesis Test Results:
#   Test statistic (t): 10.7050
#   p-value:            0.000000
#
#   p-value (0.000000) < alpha (0.05)
#   REJECT H0: The training program significantly improved productivity!

# %% [markdown]
# ## 🌟 Exercise 7 : Complex Array Comparison
# ### Instructions
# Create two arrays and perform element-wise comparison to find which elements are greater in the first array.
#
# The expected output is a boolean array showing which elements in the first array are greater than the corresponding elements in the second array.

# %%
# Generate two 10-element arrays of random integers between 1 and 10
arr1 = rng.integers(low=1, high=11, size=(10,))
arr2 = rng.integers(low=1, high=11, size=(10,))

print("Array 1:")
print(arr1)
print("Array 2:")
print(arr2)
print()
# Create boolean mask for elements in arr1 greater than arr2
greater_than = arr1 > arr2

print("Elements of Array 1 greater then corresponding elements of Array 2:")
print(arr1[greater_than])
# Out:
# Array 1:
# [ 1  4  6  8  9  1  2  3  4 10]
# Array 2:
# [ 8  4 10  5  6  5  2 10  1  2]
#
# Elements of Array 1 greater then corresponding elements of Array 2:
# [ 8  9  4 10]

# %% [markdown]
# ## 🌟 Exercise 8 : Time Series Data Manipulation
# ### Instructions
# Generate time series data for the year 2023. Demonstrate slicing for the following intervals:
#
# - January to March
# - April to June
# - July to September
# - October to December
#
# Generate a time series data for a specific period and demonstrate how to slice this data for different intervals.

# %% [markdown]
# ### Solution

# %%
# Create time series with all dates in 2023
dates = np.arange('2023-01-01', '2024-01-01', dtype='datetime64[D]')

# Create list with cutoff dates for each quarter
quarters = [
    ("Q1: Jan-Mar", '2023-01-01', '2023-04-01'),
    ("Q2: Apr-Jun", '2023-04-01', '2023-07-01'),
    ("Q3: Jul-Sep", '2023-07-01', '2023-10-01'),
    ("Q4: Oct-Dec", '2023-10-01', '2024-01-01'),
]

# Print all dates for each quarter
for name, start, end in quarters:
    mask = (dates >= np.datetime64(start)) & (dates < np.datetime64(end))  # boolean mask for this quarter
    print(f"{name}")
    print(dates[mask])
# Out:
# Q1: Jan-Mar
# ['2023-01-01' '2023-01-02' '2023-01-03' '2023-01-04' '2023-01-05'
#  '2023-01-06' '2023-01-07' '2023-01-08' '2023-01-09' '2023-01-10'
#  '2023-01-11' '2023-01-12' '2023-01-13' '2023-01-14' '2023-01-15'
#  '2023-01-16' '2023-01-17' '2023-01-18' '2023-01-19' '2023-01-20'
#  '2023-01-21' '2023-01-22' '2023-01-23' '2023-01-24' '2023-01-25'
#  '2023-01-26' '2023-01-27' '2023-01-28' '2023-01-29' '2023-01-30'
#  '2023-01-31' '2023-02-01' '2023-02-02' '2023-02-03' '2023-02-04'
#  '2023-02-05' '2023-02-06' '2023-02-07' '2023-02-08' '2023-02-09'
#  '2023-02-10' '2023-02-11' '2023-02-12' '2023-02-13' '2023-02-14'
#  '2023-02-15' '2023-02-16' '2023-02-17' '2023-02-18' '2023-02-19'
#  '2023-02-20' '2023-02-21' '2023-02-22' '2023-02-23' '2023-02-24'
#  '2023-02-25' '2023-02-26' '2023-02-27' '2023-02-28' '2023-03-01'
#  '2023-03-02' '2023-03-03' '2023-03-04' '2023-03-05' '2023-03-06'
#  '2023-03-07' '2023-03-08' '2023-03-09' '2023-03-10' '2023-03-11'
# ...

# %% [markdown]
# ## 🌟 Exercise 9 : Data Conversion
# ### Instructions
# Demonstrate how to convert a NumPy array to a Pandas DataFrame and vice versa.

# %% [markdown]
# ### Solution

# %%
# Start with pandas, extract NumPy arrays
iris = sns.load_dataset('iris')
print("Iris dataset (pandas):")
print(iris.head())
print(f"Type: {type(iris)}")
print()

# Extract numeric columns as a NumPy array
numeric_data = iris.iloc[:5, :4] # The first 5 rows up to the 4th column
arr = numeric_data.values
print(arr)
print(f"Type: {type(arr)}")
# Out:
# Iris dataset (pandas):
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Type: <class 'pandas.DataFrame'>
#
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# Type: <class 'numpy.ndarray'>

# %% [markdown]
# ## 🌟 Exercise 10 : Basic Visualization
# ### Instructions
# Use Matplotlib to visualize a simple dataset created with NumPy (e.g., a line graph of random numbers).

# %% [markdown]
# ### Solution

# %%
# Scatter plot with NumPy-generated data
x = rng.uniform(low=20, high=80, size=(100,))
y = 2.5 * x + rng.normal(loc=0, scale=15, size=(100,)) + 10

plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.6, color='steelblue', edgecolor='white', s=60)
plt.xlabel('X', fontsize=12)
plt.ylabel('Y', fontsize=12)
plt.title('Scatter Plot', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
