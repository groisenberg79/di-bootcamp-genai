# %% [markdown]
# ### 🌟 Exercise 1: Basic Usage of SciPy
# - **Task**: Import the SciPy library and explore its version.

# %% [markdown]
# ### Solution

# %%
import pandas as pd
import numpy as np
import scipy
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.stats import norm, ttest_ind, pearsonr, spearmanr

# %%
print(scipy.__version__)
# Out:
# 1.17.0

# %% [markdown]
# ### 🌟 Exercise 2: Descriptive Statistics
# - **Task**: Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# - Sample Dataset:
# ```
# data = [12, 15, 13, 12, 18, 20, 22, 21]
# ```

# %% [markdown]
# ### Solution

# %%
data = np.array([12, 15, 13, 12, 18, 20, 22, 21])

mean_scipy = stats.tmean(data)
median_scipy = np.median(data)  # SciPy does not have a separate median function
variance_scipy = stats.tvar(data)
std_dev_scipy = stats.tstd(data)

print(f'mean: {mean_scipy}')
print(f"median: {median_scipy}")
print(f"variance: {variance_scipy.round(2)}")
print(f"standard deviation: {std_dev_scipy.round(2)}")
# Out:
# mean: 16.625
# median: 16.5
# variance: 17.12
# standard deviation: 4.14

# %% [markdown]
# ### 🌟 Exercise 3: Understanding Distributions
# - **Task**: Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.

# %% [markdown]
# ### Solution

# %%
mean = 50
std_dev = 10
sample_size = 1000

# Generate random samples
# loc is the mean, scale is the standard deviation
# size is the number of samples to generate
samples = norm.rvs(loc=mean, scale=std_dev, size=sample_size)

# Plot a histogram of the samples to visualize the distribution
plt.hist(samples, bins=30, density=True, alpha=0.6, color='g')
plt.title('Histogram of Normal Distribution Samples')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### 🌟 Exercise 4: T-Test Application
# - **Task**: Perform a T-test on two sets of randomly generated data.

# %% [markdown]
# ### Solution

# %%
data1 = np.random.normal(50, 10, 100)
data2 = np.random.normal(60, 10, 100)

# Perform T-test
t_stat, p_val = ttest_ind(data1, data2)

print(f"t-statistic: {abs(t_stat).round(2)}")
print(f"p-value: {p_val.round(2)}")
# Out:
# t-statistic: 8.38
# p-value: 0.0

# %% [markdown]
# ### 🌟 Exercise 5: Linear Regression Analysis
# **Objective**: Apply linear regression to a dataset and interpret the results.
#
# - **Task**: Given a dataset of housing prices (house_prices) and their corresponding sizes (house_sizes), use linear regression to predict the price of a house given its size.
#
# - **Dataset**:
#     - house_sizes: [50, 70, 80, 100, 120] (in square meters)
#     - house_prices: [150,000, 200,000, 210,000, 250,000, 280,000] (in currency units)
#
# - **Questions**:
#     - What is the slope and intercept of the regression line?
#     - Predict the price of a house that is 90 square meters.
#     - Interpret the meaning of the slope in the context of housing prices.

# %% [markdown]
# ### Solution

# %%
house_sizes = [50, 70, 80, 100, 120]
house_prices = [150000, 200000, 210000, 250000, 280000]

# Performing linear regression
slope, intercept,_ , _ , _ = stats.linregress(house_sizes, house_prices)

print(f"Slope of the regression line: {slope.round(2)}")
print(f"Intercept of the regression line: {intercept.round(2)}")
print(f"Prediction for a house that is 90 squared meters: ${(intercept + slope * 90).round(2)}.")
print(f"The meaning of the slope: for each extra square meter, the price increases by ${slope.round(2)}")
# Out:
# Slope of the regression line: 1828.77
# Intercept of the regression line: 64383.56
# Prediction for a house that is 90 squared meters: $228972.6.
# The meaning of the slope: for each extra square meter, the price increases by $1828.77

# %% [markdown]
# ### 🌟 Exercise 6: Understanding ANOVA
# **Objective**: Test understanding of ANOVA and its application.
#
# - **Task**: Three different fertilizers are applied to three separate groups of plants to test their effectiveness. The growth in centimeters is recorded.
#
# - **Dataset**:
#     - `fertilizer_1`: `[5, 6, 7, 6, 5]`
#     - `fertilizer_2`: `[7, 8, 7, 9, 8]`
#     - `fertilizer_3`: `[4, 5, 4, 3, 4]`
#
# - **Questions**:
#     - Perform an ANOVA test on the given data. What are the F-value and P-value?
#     - Based on the P-value, do the fertilizers have significantly different effects on plant growth?
#     - Explain what would happen if the P-value were greater than 0.05.

# %% [markdown]
# ### Solution

# %%
fertilizer_1 = [5, 6, 7, 6, 5]
fertilizer_2 = [7, 8, 7, 9, 8]
fertilizer_3 = [4, 5, 4, 3, 4]

# Performing one-way ANOVA
f_value, p_value = stats.f_oneway(fertilizer_1, fertilizer_2, fertilizer_3)
print("F-value:", f_value.round(2))
print("P-value:", p_value.round(2))
print()

alpha = 0.05
if p_value < alpha:
    print(f"p={p_value:.4f} < {alpha} → REJECT H0")
    print("Fertilizers have a significant effect on plant growth.")
else:
    print(f"p={p_value:.4f} >= {alpha} → Fail to reject H0")
    print("No significant difference with the use of fertilizers.")
print()

print("If we had p_value >= 0.05, we would conclude that fertilizers have no effect on plant growth.")
# Out:
# F-value: 28.53
# P-value: 0.0
#
# p=0.0000 < 0.05 → REJECT H0
# Fertilizers have a significant effect on plant growth.
#
# If we had p_value >= 0.05, we would conclude that fertilizers have no effect on plant growth.

# %% [markdown]
# ### 🌟 Exercise 7: Probability Distributions (Optional)
# - Work with a binomial distribution: calculate probabilities for different numbers of successes.
# - Example: Calculating the probability of getting exactly 5 heads in 10 coin flips.

# %% [markdown]
# ### Solution

# %%
# Calculate Binomial Distribution
n, p = 10, 0.5  # number of trials, probability of each trial
binom_dist = stats.binom(n, p)
print(f"Probablity of getting 5 heads in 10 coin flips: {binom_dist.pmf(5).round(3) * 100}%")
# Out:
# Probablity of getting 5 heads in 10 coin flips: 24.6%

# %% [markdown]
# ### 🌟 Exercise 8: Correlation Coefficients (Optional)
# - Calculate the Pearson and Spearman correlation coefficients between two variables in a dataset.
# - Example in code:
# ```
# data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})
# ```

# %% [markdown]
# ### Solution

# %%
data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})

corr_pearson, _ = pearsonr(data['age'], data['income'])
corr_spearman, _ = spearmanr(data['age'], data['income'])

print(f'Pearson Correlation Coefficient: {corr_pearson:.2f}')
print(f'Spearman Rank Correlation: {corr_spearman:.2f}')
# Out:
# Pearson Correlation Coefficient: 1.00
# Spearman Rank Correlation: 1.00
